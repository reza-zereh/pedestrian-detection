# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/drive/1BMa-vXfn4fiz4zNoVLG8pJxAI3ZFNzgW?usp=share_link">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# %%capture
! pip install pip==21.3.1
! pip install ultralytics==8.0.53
! pip install clearml==1.9.3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from glob import glob
import numpy as np
import torch
import ultralytics
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow
from PIL import Image
import clearml
from clearml import Task

# %%
class cnf:
    PROJECT_NAME = "Pedestrian-Detection-YOLOv8"
    TASK_NAME = "yolov8m_imgsz1024_epochs75"
    CKPT = "yolov8m.pt"
    IMGSZ = 1024
    EPOCHS = 75

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.53 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 25.5/166.8 GB disk)

# %%
clearml.browser_login()
# Out:
# 🤖 ClearML connected successfully - let's build something! 🚀

# %%
# %%shell
# cp /content/drive/MyDrive/Reza/Projects/Pedestrian-Detection/data/citypersons.zip .
# unzip -q citypersons.zip

# %%
# create ClearML experiment and task
task = Task.init(project_name=cnf.PROJECT_NAME, task_name=cnf.TASK_NAME)
# Out:
# ClearML Task: created new task id=cf2bd7609ce84cc69e6705dc9a263123
# 2023-03-19 19:46:48,708 - clearml.Task - INFO - Storing jupyter notebook directly as code
# ClearML results page: https://app.clear.ml/projects/c44ac5edda124f9fa0400f27bf7659c4/experiments/cf2bd7609ce84cc69e6705dc9a263123/output/log

# %%
# load a pretrained model
model = YOLO(cnf.CKPT)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8m.pt to yolov8m.pt...
#   0%|          | 0.00/49.7M [00:00<?, ?B/s]

# %%
# %%time
# train the model
model.train(data='/content/citypersons/dataset.yaml', 
            imgsz=cnf.IMGSZ, 
            epochs=cnf.EPOCHS)
# Out:
# New https://pypi.org/project/ultralytics/8.0.54 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.53 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8m.pt, data=/content/citypersons/dataset.yaml, epochs=75, patience=50, batch=16, imgsz=1024, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
#   0%|          | 0.00/755k [00:00<?, ?B/s]
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.Conv                  [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.Conv                  [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.C2f                   [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.Conv                  [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.C2f                   [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.Conv                  [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.C2f                   [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.Conv                  [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.C2f                   [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.SPPF                  [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.C2f                   [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  2    517632  ultralytics.nn.modules.C2f                   [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.Conv                  [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.C2f                   [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.Conv                  [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.C2f                   [960, 576, 2]
#  22        [15, 18, 21]  1   3776854  ultralytics.nn.modules.Detect                [2, [192, 384, 576]]
# Model summary: 295 layers, 25857478 parameters, 25857462 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# WARNING ⚠️ ClearML installed but not initialized correctly, not logging this run. Current task already created and requested project name 'YOLOv8' does not match current project name 'Pedestrian-Detection-YOLOv8'. If you wish to create additional tasks use `Task.create`, or close the current task with `task.close()` before calling `Task.init(...)`
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.util has been moved to tensorflow.python.checkpoint.checkpoint. The old module will be deleted in version 2.11.
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
#   0%|          | 0.00/6.23M [00:00<?, ?B/s]
# 2023-03-19 19:47:21,444 - clearml.model - INFO - Selected model id: 96920760883b420098dc25cc39edaf86
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias
# train: Scanning /content/citypersons/train/labels... 2500 images, 50 backgrounds, 0 corrupt: 100%|██████████| 2550/2550 [00:03<00:00, 717.69it/s]
# train: New cache created: /content/citypersons/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/citypersons/valid/labels... 441 images, 10 backgrounds, 0 corrupt: 100%|██████████| 451/451 [00:00<00:00, 721.17it/s]
# val: New cache created: /content/citypersons/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# Image sizes 1024 train, 1024 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 75 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/75      17.2G       1.47      1.485      1.076        128       1024: 100%|██████████| 160/160 [00:54<00:00,  2.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:06<00:00,  2.21it/s]
#                    all        451       4164      0.757      0.477      0.555      0.351
# 2023-03-19 19:48:50,816 - clearml.frameworks - INFO - Found existing registered model id=3f6fb710d3634d36ad6e029b3808e613 [/content/runs/detect/train/weights/last.pt] reusing it.
# 2023-03-19 19:49:02,195 - clearml.frameworks - INFO - Found existing registered model id=e962754b91194f3c8c9a912133edcac3 [/content/runs/detect/train/weights/best.pt] reusing it.
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/75      17.2G      1.289      1.008          1         99       1024: 100%|██████████| 160/160 [00:49<00:00,  3.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        451       4164      0.745       0.49      0.579      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/75      17.2G      1.323      1.053      1.011         91       1024: 100%|██████████| 160/160 [00:48<00:00,  3.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.74it/s]
#                    all        451       4164      0.721      0.468      0.526      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/75      17.2G      1.321      1.031      1.027         25       1024: 100%|██████████| 160/160 [00:49<00:00,  3.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.74it/s]
#                    all        451       4164      0.696      0.462      0.534      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/75      18.2G      1.297     0.9962       1.02         71       1024: 100%|██████████| 160/160 [00:48<00:00,  3.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.72it/s]
#                    all        451       4164      0.721      0.457      0.537      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/75      18.2G      1.266     0.9658      1.013        111       1024: 100%|██████████| 160/160 [00:49<00:00,  3.23it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        451       4164      0.748      0.471      0.554      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/75      18.2G      1.238     0.9344      1.005         88       1024: 100%|██████████| 160/160 [00:48<00:00,  3.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.67it/s]
#                    all        451       4164      0.725      0.494       0.56      0.363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/75      18.2G      1.221     0.9102     0.9981        121       1024: 100%|██████████| 160/160 [00:48<00:00,  3.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.69it/s]
#                    all        451       4164      0.754      0.478      0.553      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/75      18.2G      1.203      0.901     0.9969        108       1024: 100%|██████████| 160/160 [00:48<00:00,  3.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.69it/s]
#                    all        451       4164      0.717        0.5      0.567      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/75      18.2G      1.182     0.8657     0.9847        143       1024: 100%|██████████| 160/160 [00:49<00:00,  3.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.70it/s]
#                    all        451       4164      0.736      0.489      0.568      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/75      18.2G      1.165     0.8565     0.9856         98       1024: 100%|██████████| 160/160 [00:48<00:00,  3.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.70it/s]
#                    all        451       4164      0.748      0.501       0.58      0.384
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/75      18.2G      1.164       0.85     0.9831        155       1024: 100%|██████████| 160/160 [00:49<00:00,  3.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.73it/s]
#                    all        451       4164      0.724      0.494       0.57      0.381
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/75      18.2G      1.134     0.8241     0.9773        167       1024: 100%|██████████| 160/160 [00:48<00:00,  3.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.68it/s]
#                    all        451       4164      0.748      0.497      0.581       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/75      18.2G      1.131     0.8214     0.9706        106       1024: 100%|██████████| 160/160 [00:49<00:00,  3.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.70it/s]
#                    all        451       4164      0.728      0.496      0.581      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/75      18.2G      1.121     0.8041     0.9655        124       1024: 100%|██████████| 160/160 [00:48<00:00,  3.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.67it/s]
#                    all        451       4164      0.755      0.488      0.572      0.381
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/75      18.2G      1.097     0.7885     0.9601        107       1024: 100%|██████████| 160/160 [00:48<00:00,  3.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.70it/s]
#                    all        451       4164      0.722      0.512      0.586      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/75      18.2G      1.093     0.7805     0.9567         66       1024: 100%|██████████| 160/160 [00:49<00:00,  3.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        451       4164      0.739      0.519      0.592      0.398
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/75      18.2G      1.079     0.7647     0.9539         59       1024: 100%|██████████| 160/160 [00:48<00:00,  3.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.69it/s]
#                    all        451       4164      0.752      0.509      0.578       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/75      18.2G      1.078     0.7629     0.9536         88       1024: 100%|██████████| 160/160 [00:49<00:00,  3.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.68it/s]
#                    all        451       4164       0.75      0.521      0.606      0.409
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/75      18.2G      1.073     0.7598     0.9504        103       1024: 100%|██████████| 160/160 [00:48<00:00,  3.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.73it/s]
#                    all        451       4164      0.736      0.522      0.598      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/75      18.2G      1.063     0.7464     0.9536         74       1024: 100%|██████████| 160/160 [00:48<00:00,  3.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.70it/s]
#                    all        451       4164      0.728      0.528      0.594      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/75      18.2G      1.058     0.7377     0.9451         76       1024: 100%|██████████| 160/160 [00:49<00:00,  3.23it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        451       4164      0.795      0.518      0.598      0.401
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/75      18.2G      1.045     0.7343     0.9439         50       1024: 100%|██████████| 160/160 [00:48<00:00,  3.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.73it/s]
#                    all        451       4164      0.734      0.534      0.607      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/75      18.2G      1.038     0.7202     0.9409        111       1024: 100%|██████████| 160/160 [00:48<00:00,  3.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.69it/s]
#                    all        451       4164      0.766      0.526        0.6      0.409
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/75      18.2G      1.022      0.706     0.9365         40       1024: 100%|██████████| 160/160 [00:49<00:00,  3.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        451       4164      0.762      0.529      0.612      0.412
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        451       4164      0.777      0.521        0.6      0.409
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/75      18.2G      1.003     0.6894     0.9321        108       1024: 100%|██████████| 160/160 [00:48<00:00,  3.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.70it/s]
#                    all        451       4164      0.759      0.535      0.609      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/75      18.2G      1.001     0.6807     0.9266         74       1024: 100%|██████████| 160/160 [00:49<00:00,  3.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.70it/s]
#                    all        451       4164      0.797      0.515      0.605      0.412
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/75      18.2G     0.9946     0.6753     0.9289        144       1024: 100%|██████████| 160/160 [00:48<00:00,  3.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        451       4164      0.765       0.53       0.61      0.418
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/75      18.2G     0.9961     0.6691     0.9265         98       1024: 100%|██████████| 160/160 [00:49<00:00,  3.23it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.70it/s]
#                    all        451       4164      0.756       0.54      0.615      0.418
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/75      18.2G     0.9781     0.6626     0.9241         99       1024: 100%|██████████| 160/160 [00:49<00:00,  3.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        451       4164      0.777      0.531      0.621       0.42
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/75      18.2G     0.9756     0.6546     0.9223        103       1024: 100%|██████████| 160/160 [00:48<00:00,  3.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        451       4164      0.746      0.543      0.619      0.424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/75      18.2G     0.9674     0.6541     0.9184        100       1024: 100%|██████████| 160/160 [00:48<00:00,  3.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.67it/s]
#                    all        451       4164       0.76      0.526      0.615      0.424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/75      18.2G     0.9651     0.6451     0.9141         99       1024: 100%|██████████| 160/160 [00:49<00:00,  3.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.64it/s]
#                    all        451       4164      0.777      0.531      0.614      0.415
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/75      18.2G     0.9465     0.6338     0.9113         67       1024: 100%|██████████| 160/160 [00:48<00:00,  3.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.70it/s]
#                    all        451       4164      0.738      0.539      0.617      0.424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/75      18.2G     0.9453     0.6256     0.9135        132       1024: 100%|██████████| 160/160 [00:49<00:00,  3.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.69it/s]
#                    all        451       4164      0.778      0.533      0.612      0.417
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/75      18.2G      0.953     0.6237     0.9081         58       1024: 100%|██████████| 160/160 [00:49<00:00,  3.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.72it/s]
#                    all        451       4164      0.758      0.538      0.617      0.418
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/75      18.2G     0.9328     0.6166     0.9034         83       1024: 100%|██████████| 160/160 [00:49<00:00,  3.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.69it/s]
#                    all        451       4164      0.811      0.524      0.616      0.425
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/75      18.2G     0.9272     0.6082     0.9042        121       1024: 100%|██████████| 160/160 [00:48<00:00,  3.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.74it/s]
#                    all        451       4164      0.757       0.54      0.622      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/75      18.2G     0.9208     0.5988     0.9007         79       1024: 100%|██████████| 160/160 [00:48<00:00,  3.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.66it/s]
#                    all        451       4164       0.76      0.547      0.622      0.425
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/75      18.2G     0.9103     0.5922     0.9024        151       1024: 100%|██████████| 160/160 [00:49<00:00,  3.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.60it/s]
#                    all        451       4164      0.763      0.547      0.617      0.427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/75      18.2G     0.9146     0.5899     0.8976         62       1024: 100%|██████████| 160/160 [00:48<00:00,  3.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        451       4164       0.75      0.541      0.615      0.423
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/75      18.2G     0.9016     0.5812     0.8968        148       1024: 100%|██████████| 160/160 [00:49<00:00,  3.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.72it/s]
#                    all        451       4164       0.79      0.523      0.615      0.423
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/75      18.2G     0.8912     0.5758     0.8932         73       1024: 100%|██████████| 160/160 [00:49<00:00,  3.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.73it/s]
#                    all        451       4164      0.775      0.529      0.622      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/75      18.2G     0.8928     0.5727     0.8889         83       1024: 100%|██████████| 160/160 [00:48<00:00,  3.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.69it/s]
#                    all        451       4164      0.763      0.537      0.617      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/75      18.2G     0.8907     0.5693     0.8932         26       1024: 100%|██████████| 160/160 [00:48<00:00,  3.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        451       4164      0.772      0.536      0.612      0.419
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/75      18.2G     0.8825      0.564     0.8903         54       1024: 100%|██████████| 160/160 [00:48<00:00,  3.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.69it/s]
#                    all        451       4164       0.79      0.521      0.618      0.421
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/75      18.2G     0.8638      0.551     0.8828        101       1024: 100%|██████████| 160/160 [00:49<00:00,  3.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.73it/s]
#                    all        451       4164      0.752      0.538      0.618      0.424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/75      18.2G     0.8588     0.5444     0.8851         53       1024: 100%|██████████| 160/160 [00:48<00:00,  3.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.70it/s]
#                    all        451       4164      0.742      0.545      0.619      0.427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/75      18.2G     0.8513     0.5356     0.8777         59       1024: 100%|██████████| 160/160 [00:49<00:00,  3.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.68it/s]
#                    all        451       4164      0.747      0.545      0.613      0.424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/75      18.2G     0.8524     0.5353     0.8802         77       1024: 100%|██████████| 160/160 [00:48<00:00,  3.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.70it/s]
#                    all        451       4164       0.76      0.543      0.623      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/75      18.2G     0.8467     0.5338     0.8802        101       1024: 100%|██████████| 160/160 [00:49<00:00,  3.23it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.68it/s]
#                    all        451       4164      0.748      0.551      0.624       0.43
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/75      18.2G     0.8296     0.5202     0.8753        198       1024: 100%|██████████| 160/160 [00:49<00:00,  3.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.70it/s]
#                    all        451       4164      0.776      0.527      0.618      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/75      18.2G     0.8209     0.5155     0.8745         77       1024: 100%|██████████| 160/160 [00:48<00:00,  3.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.68it/s]
#                    all        451       4164      0.768      0.532      0.617      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/75      18.2G     0.8176     0.5122     0.8715         80       1024: 100%|██████████| 160/160 [00:48<00:00,  3.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.69it/s]
#                    all        451       4164      0.764      0.527       0.61      0.424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/75      18.2G      0.825     0.5126     0.8727        116       1024: 100%|██████████| 160/160 [00:49<00:00,  3.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.69it/s]
#                    all        451       4164       0.76      0.537      0.615      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/75      18.2G     0.8191     0.5088     0.8713         75       1024: 100%|██████████| 160/160 [00:49<00:00,  3.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        451       4164      0.766      0.534      0.614      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/75      18.2G     0.8012     0.4962     0.8654         52       1024: 100%|██████████| 160/160 [00:48<00:00,  3.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.70it/s]
#                    all        451       4164      0.761      0.536      0.619      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/75      18.2G     0.7964     0.4886     0.8652         82       1024: 100%|██████████| 160/160 [00:49<00:00,  3.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.67it/s]
#                    all        451       4164      0.765      0.533      0.614      0.427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/75      18.2G     0.8001     0.4901     0.8642         59       1024: 100%|██████████| 160/160 [00:48<00:00,  3.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.67it/s]
#                    all        451       4164      0.761      0.545      0.616      0.431
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       61/75      18.2G       0.78     0.4806     0.8615         57       1024: 100%|██████████| 160/160 [00:49<00:00,  3.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.68it/s]
#                    all        451       4164      0.759       0.55       0.62       0.43
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       62/75      18.2G     0.7779     0.4793     0.8601        136       1024: 100%|██████████| 160/160 [00:47<00:00,  3.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.70it/s]
#                    all        451       4164      0.771      0.537      0.619       0.43
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       63/75      18.2G     0.7694     0.4663     0.8603        129       1024: 100%|██████████| 160/160 [00:48<00:00,  3.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.73it/s]
#                    all        451       4164      0.796      0.527      0.618       0.43
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       64/75      18.2G      0.763     0.4667     0.8561        119       1024: 100%|██████████| 160/160 [00:48<00:00,  3.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.72it/s]
#                    all        451       4164      0.764      0.534       0.62      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       65/75      18.2G     0.7619     0.4673     0.8556         77       1024: 100%|██████████| 160/160 [00:49<00:00,  3.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        451       4164      0.768      0.534      0.617       0.43
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       66/75      18.2G     0.7552     0.4575     0.8561         27       1024: 100%|██████████| 160/160 [00:44<00:00,  3.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.66it/s]
#                    all        451       4164       0.74      0.553      0.616       0.43
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       67/75      18.2G     0.7396     0.4457     0.8476         33       1024: 100%|██████████| 160/160 [00:41<00:00,  3.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.68it/s]
#                    all        451       4164      0.789      0.519       0.61      0.425
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       68/75      18.2G     0.7283     0.4381     0.8474         37       1024: 100%|██████████| 160/160 [00:41<00:00,  3.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.70it/s]
#                    all        451       4164      0.756      0.539      0.612      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       69/75      18.2G     0.7345     0.4382     0.8474         32       1024: 100%|██████████| 160/160 [00:41<00:00,  3.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.68it/s]
#                    all        451       4164      0.772       0.53      0.615      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       70/75      18.2G     0.7242     0.4327     0.8458         85       1024: 100%|██████████| 160/160 [00:41<00:00,  3.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.69it/s]
#                    all        451       4164      0.787      0.532      0.615      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       71/75      18.2G     0.7147      0.427     0.8413         37       1024: 100%|██████████| 160/160 [00:41<00:00,  3.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.70it/s]
#                    all        451       4164      0.751       0.54       0.61      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       72/75      18.2G     0.7092     0.4205     0.8436         42       1024: 100%|██████████| 160/160 [00:41<00:00,  3.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        451       4164      0.763      0.537      0.613      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       73/75      18.2G     0.6993     0.4152     0.8406         37       1024: 100%|██████████| 160/160 [00:40<00:00,  3.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.67it/s]
#                    all        451       4164      0.773      0.536      0.616      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       74/75      18.2G     0.7006     0.4147     0.8398         16       1024: 100%|██████████| 160/160 [00:41<00:00,  3.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.70it/s]
#                    all        451       4164      0.804      0.522      0.614      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       75/75      18.2G     0.6897     0.4041     0.8344         41       1024: 100%|██████████| 160/160 [00:41<00:00,  3.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:11<00:00,  1.32it/s]
#                    all        451       4164      0.781       0.53      0.614      0.428
#
# 75 epochs completed in 1.431 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 52.0MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 52.0MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.53 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:11<00:00,  1.36it/s]
#                    all        451       4164      0.759      0.543      0.623      0.433
#                  rider        451       1007      0.707      0.413      0.475      0.317
#             pedestrian        451       3157      0.811      0.674      0.771      0.548
# Speed: 0.6ms preprocess, 2.1ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to runs/detect/train
# CPU times: user 1h 45s, sys: 6min 59s, total: 1h 7min 44s
# Wall time: 1h 27min 45s

# %%
# close clearml task
task.close()

# %%
# helper functions for ploting predictions
def box_label(image, box, label='', color=(128, 128, 128), txt_color=(255, 255, 255)):
  lw = max(round(sum(image.shape) / 2 * 0.003), 2)
  p1, p2 = (int(box[0]), int(box[1])), (int(box[2]), int(box[3]))
  cv2.rectangle(image, p1, p2, color, thickness=lw, lineType=cv2.LINE_AA)
  if label:
    tf = max(lw - 1, 1)  # font thickness
    w, h = cv2.getTextSize(label, 0, fontScale=lw / 3, thickness=tf)[0]  # text width, height
    outside = p1[1] - h >= 3
    p2 = p1[0] + w, p1[1] - h - 3 if outside else p1[1] + h + 3
    cv2.rectangle(image, p1, p2, color, -1, cv2.LINE_AA)  # filled
    cv2.putText(image,
                label, (p1[0], p1[1] - 2 if outside else p1[1] + h + 2),
                0,
                lw / 3,
                txt_color,
                thickness=tf,
                lineType=cv2.LINE_AA)
    
def plot_bboxes(image, boxes, labels=[], colors=[], score=True, conf=None):
  # Define Labels
  if labels == []:
    labels = {0: u'__background__', 1: u'rider', 2: u'pedestrian'}
  # Define colors
  if colors == []:
    
    colors = [(89, 161, 197), (190, 76, 98), (130, 172, 179), 
              (67, 161, 255),(19, 222, 24),(186, 55, 2),
              (167, 146, 11),(130, 172, 179),(115, 209, 128),
              (204, 79, 135),(136, 126, 185),(209, 213, 45),]              
  
  #plot each boxes
  for box in boxes:
    #add score in label if score=True
    if score :
      label = labels[int(box[-1])+1] + " " + str(round(100 * float(box[-2]),1)) + "%"
    else :
      label = labels[int(box[-1])+1]
    #filter every box under conf threshold if conf threshold setted
    if conf :
      if box[-2] > conf:
        color = colors[int(box[-1])]
        box_label(image, box, label, color)
    else:
      color = colors[int(box[-1])]
      box_label(image, box, label, color)

  #show image
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

  try:
    import google.colab
    IN_COLAB = True
  except:
    IN_COLAB = False

  if IN_COLAB:
    cv2_imshow(image) #if used in Colab
  else :
    cv2.imshow(image) #if used in Python

# %%
# make prediction on a few validation images and plot the results
valid_images = [fp for fp in glob("/content/citypersons/valid/images/*.png")]

for fp_img in np.random.choice(valid_images, 2):
    preds = model.predict(fp_img);
    image = Image.open(fp_img)
    image = np.asarray(image)
    plot_bboxes(image, preds[0].boxes.boxes, score=False)
# Out:
# image 1/1 /content/citypersons/valid/images/frankfurt_000001_040732_leftImg8bit.png: 512x1024 2 riders, 21.7ms
# Speed: 0.6ms preprocess, 21.7ms inference, 2.3ms postprocess per image at shape (1, 3, 1024, 1024)
# <PIL.Image.Image image mode=RGB size=1024x512 at 0x7F66ED054A90>
# image 1/1 /content/citypersons/valid/images/munster_000128_000019_leftImg8bit.png: 512x1024 2 pedestrians, 22.5ms
# Speed: 0.7ms preprocess, 22.5ms inference, 2.0ms postprocess per image at shape (1, 3, 1024, 1024)
# <PIL.Image.Image image mode=RGB size=1024x512 at 0x7F653C45A9A0>
